# %% [markdown]
# O Spark pega as colunas que você especificou na repartição, faz o hash desse valor em 64b de comprimento e modula o valor pelo número de partições. Dessa forma, o número de partições é determinístico. A razão pela qual funciona dessa maneira é que as junções precisam de um número correspondente de partições nos lados esquerdo e direito de uma junção, além de garantir que o hash seja o mesmo em ambos os lados
#
# repartition()é usado para particionar dados na memória e partitionByé usado para particionar dados no disco. Eles costumam ser usados ​​em conjunto.
#
# Ambos repartition()e partitionBypodem ser usados ​​para "particionar dados com base na coluna do dataframe", mas repartition()particiona os dados na memória e partitionByparticiona os dados no disco.
#
# Partition Tuning: https://luminousmen.com/post/spark-tips-partition-tuning
# https://devblogs.microsoft.com/azure-sql/partitioning-on-spark-fast-loading-clustered-columnstore-index/
# https://towardsdatascience.com/apache-spark-performance-boosting-e072a3ec1179

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql.types import StringType

# %%
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.master("local[*]").appName("Particao 2").getOrCreate()

# %%
url = "/Users/macca/Documents/spark/pyspark_com_grimaldo/arquivo_de_dados/Bikes.csv"

# %%
df = (spark.read
      .format("csv")
      .option("header", "true")
      .option("inferSchema","true")
      .option("delimiters", ",")
      .load(url))

# %%
df.show(10)
# Out:
# +--------------------+--------+---------+----------+------------+---+-----+-------------+
# |           bike_name|   price|     city|kms_driven|       owner|age|power|        brand|
# +--------------------+--------+---------+----------+------------+---+-----+-------------+
# |TVS Star City Plu...| 35000.0|Ahmedabad|   17654.0| First Owner|3.0|110.0|          TVS|
# |Royal Enfield Cla...|119900.0|    Delhi|   11000.0| First Owner|4.0|350.0|Royal Enfield|
# |Triumph Daytona 675R|600000.0|    Delhi|     110.0| First Owner|8.0|675.0|      Triumph|
# |TVS Apache RTR 180cc| 65000.0|Bangalore|   16329.0| First Owner|4.0|180.0|          TVS|
# |Yamaha FZ S V 2.0...| 80000.0|Bangalore|   10000.0| First Owner|3.0|150.0|       Yamaha|
# |    Yamaha FZs 150cc| 53499.0|    Delhi|   25000.0| First Owner|6.0|150.0|       Yamaha|
# |Honda CB Hornet 1...| 85000.0|    Delhi|    8200.0| First Owner|3.0|160.0|        Honda|
# |Hero Splendor Plu...| 45000.0|    Delhi|   12645.0| First Owner|3.0|100.0|         Hero|
# |Royal Enfield Thu...|145000.0|Bangalore|    9190.0| First Owner|3.0|350.0|Royal Enfield|
# |Royal Enfield Cla...| 88000.0|    Delhi|   19000.0|Second Owner|7.0|500.0|Royal Enfield|
# +--------------------+--------+---------+----------+------------+---+-----+-------------+
# only showing top 10 rows

# %%
contagem = df.groupBy("city").count().show()
# Out:
# +------------+-----+
# |        city|count|
# +------------+-----+
# |   Bangalore| 2723|
# |    Zirakpur|    1|
# |      Kathua|    1|
# |      Sanand|    1|
# |     Udaipur|   12|
# |     Khandwa|    2|
# |       Kochi|    2|
# |   Faridabad|  609|
# |  Aurangabad|   18|
# |     Chenani|    3|
# |Vizianagaram|    1|
# |       Hosur|    5|
# |Swaimadhopur|    1|
# |     Sangrur|    1|
# |    Sholapur|    3|
# | Bhubaneswar|    1|
# |      Mysore|    8|
# |    Uluberia|    1|
# |    Rudrapur|    3|
# |   Ferozepur|    2|
# +------------+-----+
# only showing top 20 rows

# %%
total_Bangalore = df.filter(df.city == 'Bangalore').groupBy("owner").count().show()
# Out:
# +--------------------+-----+
# |               owner|count|
# +--------------------+-----+
# |         Third Owner|   17|
# |        Second Owner|   78|
# |         First Owner| 2625|
# |Fourth Owner Or More|    3|
# +--------------------+-----+

# %%
df.rdd.getNumPartitions()
# Out:
# 1

# %%
df.select("owner").describe().show()
# Out:
# +-------+-----------+
# |summary|      owner|
# +-------+-----------+
# |  count|      32648|
# |   mean|       null|
# | stddev|       null|
# |    min|First Owner|
# |    max|Third Owner|
# +-------+-----------+

# %%
df.createOrReplaceTempView("tab_bikes")

# %%
delhi = spark.sql("select * from tab_bikes where city='Delhi'")

# %%
delhi.show(10)
# Out:
# +--------------------+--------+-----+----------+------------+---+-----+-------------+
# |           bike_name|   price| city|kms_driven|       owner|age|power|        brand|
# +--------------------+--------+-----+----------+------------+---+-----+-------------+
# |Royal Enfield Cla...|119900.0|Delhi|   11000.0| First Owner|4.0|350.0|Royal Enfield|
# |Triumph Daytona 675R|600000.0|Delhi|     110.0| First Owner|8.0|675.0|      Triumph|
# |    Yamaha FZs 150cc| 53499.0|Delhi|   25000.0| First Owner|6.0|150.0|       Yamaha|
# |Honda CB Hornet 1...| 85000.0|Delhi|    8200.0| First Owner|3.0|160.0|        Honda|
# |Hero Splendor Plu...| 45000.0|Delhi|   12645.0| First Owner|3.0|100.0|         Hero|
# |Royal Enfield Cla...| 88000.0|Delhi|   19000.0|Second Owner|7.0|500.0|Royal Enfield|
# | Bajaj Discover 100M| 29499.0|Delhi|   20000.0| First Owner|8.0|100.0|        Bajaj|
# | Bajaj Discover 125M| 29900.0|Delhi|   20000.0| First Owner|7.0|125.0|        Bajaj|
# | Bajaj Discover 125M| 29900.0|Delhi|   20000.0| First Owner|7.0|125.0|        Bajaj|
# |Hero Splendor iSm...| 46500.0|Delhi|    3500.0| First Owner|2.0|110.0|         Hero|
# +--------------------+--------+-----+----------+------------+---+-----+-------------+
# only showing top 10 rows

# %% [markdown]
# <b> Repartition por coluna </b>

# %%
df_repartition = df.repartition("owner")

# %%
df_repartition.rdd.glom().collect()
# Out:
# [[Row(bike_name='Bajaj Pulsar 150cc', price=11100.0, city='Pune', kms_driven=12000.0, owner='Third Owner', age=12.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='KTM RC 200cc', price=113000.0, city='Kottayam', kms_driven=28000.0, owner='Third Owner', age=6.0, power=200.0, brand='KTM'),
#   Row(bike_name='Triumph Street Triple ABS 675cc', price=599999.0, city='Mumbai', kms_driven=7800.0, owner='Third Owner', age=5.0, power=675.0, brand='Triumph'),
#   Row(bike_name='Kawasaki Ninja 250cc', price=125000.0, city='Coimbatore', kms_driven=21000.0, owner='Third Owner', age=11.0, power=250.0, brand='Kawasaki'),
#   Row(bike_name='Mahindra Centuro Rockstar 110cc', price=18999.0, city='Pune', kms_driven=38669.0, owner='Third Owner', age=6.0, power=110.0, brand='Mahindra'),
#   Row(bike_name='Royal Enfield Bullet Electra Twinspark 350cc', price=85000.0, city='Palwal', kms_driven=23399.0, owner='Third Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Bullet Electra Twinspark 350cc', price=85000.0, city='Palwal', kms_driven=23399.0, owner='Third Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Karizma R 223cc', price=27000.0, city='Bangalore', kms_driven=101250.0, owner='Third Owner', age=14.0, power=223.0, brand='Hero'),
#   Row(bike_name='KTM Duke 200cc', price=61000.0, city='Delhi', kms_driven=16000.0, owner='Third Owner', age=9.0, power=200.0, brand='KTM'),
#   Row(bike_name='Royal Enfield Thunderbird 500cc', price=119000.0, city='Bangalore', kms_driven=11976.0, owner='Third Owner', age=6.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Karizma R 223cc', price=27000.0, city='Bangalore', kms_driven=101250.0, owner='Third Owner', age=14.0, power=223.0, brand='Hero'),
#   Row(bike_name='Hero CBZ Xtreme 150cc', price=14800.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=10.0, power=150.0, brand='Hero'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=25000.0, city='Pune', kms_driven=86283.0, owner='Third Owner', age=10.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Discover 135cc', price=14000.0, city='Mumbai', kms_driven=25398.0, owner='Third Owner', age=13.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Discover 135cc', price=14000.0, city='Mumbai', kms_driven=25398.0, owner='Third Owner', age=13.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=25000.0, city='Pune', kms_driven=86283.0, owner='Third Owner', age=10.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Honda CBR 250R ABS', price=62700.0, city='Mumbai', kms_driven=5678.0, owner='Third Owner', age=9.0, power=250.0, brand='Honda'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=15000.0, city='Ahmedabad', kms_driven=34710.0, owner='Third Owner', age=14.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Yamaha RX135 135cc 4-Speed', price=85000.0, city='Mumbai', kms_driven=300.0, owner='Third Owner', age=24.0, power=135.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Avenger Cruise 220', price=55000.0, city='Pune', kms_driven=13157.0, owner='Third Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger Cruise 220', price=55000.0, city='Pune', kms_driven=13157.0, owner='Third Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Honda CB Trigger 150cc', price=30000.0, city='Bangalore', kms_driven=28524.0, owner='Third Owner', age=8.0, power=150.0, brand='Honda'),
#   Row(bike_name='Honda CBR 150R 150cc', price=55000.0, city='Jodhpur', kms_driven=25000.0, owner='Third Owner', age=8.0, power=150.0, brand='Honda'),
#   Row(bike_name='Honda CB Shine 125cc', price=17000.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=10.0, power=125.0, brand='Honda'),
#   Row(bike_name='Yamaha YZF-R15 150cc', price=33000.0, city='Jhajjar', kms_driven=57000.0, owner='Third Owner', age=10.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Thunderbird 500cc', price=95000.0, city='Ahmedabad', kms_driven=30000.0, owner='Third Owner', age=8.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Discover 150F', price=31000.0, city='Kolkata', kms_driven=17000.0, owner='Third Owner', age=5.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=95000.0, city='Bangalore', kms_driven=50000.0, owner='Third Owner', age=43.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=95000.0, city='Bangalore', kms_driven=50000.0, owner='Third Owner', age=43.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=56000.0, city='Lucknow', kms_driven=29339.0, owner='Third Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Honda CB Shine 125cc', price=17000.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=10.0, power=125.0, brand='Honda'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=54000.0, city='Azamgarh', kms_driven=40000.0, owner='Third Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Suzuki Gixxer 150cc', price=32000.0, city='Trivandrum', kms_driven=59500.0, owner='Third Owner', age=5.0, power=150.0, brand='Suzuki'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=56000.0, city='Lucknow', kms_driven=29339.0, owner='Third Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Pulsar 135LS', price=17000.0, city='Ahmedabad', kms_driven=59162.0, owner='Third Owner', age=9.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Hyosung Aquila GV250', price=140000.0, city='Pune', kms_driven=27000.0, owner='Third Owner', age=7.0, power=250.0, brand='Hyosung'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=75000.0, city='Bardhaman', kms_driven=22000.0, owner='Third Owner', age=10.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Harley-Davidson Street 750', price=330000.0, city='Delhi', kms_driven=14000.0, owner='Third Owner', age=6.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='KTM RC 390cc', price=130000.0, city='Bangalore', kms_driven=8000.0, owner='Third Owner', age=6.0, power=390.0, brand='KTM'),
#   Row(bike_name='TVS Apache RTR 160cc', price=31000.0, city='Ahmedabad', kms_driven=37594.0, owner='Third Owner', age=6.0, power=160.0, brand='TVS'),
#   Row(bike_name='Hero Karizma R 223cc', price=17000.0, city='Dehradun', kms_driven=40155.0, owner='Third Owner', age=14.0, power=223.0, brand='Hero'),
#   Row(bike_name='Harley-Davidson Street 750', price=330000.0, city='Delhi', kms_driven=14000.0, owner='Third Owner', age=6.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='KTM RC 390cc', price=130000.0, city='Bangalore', kms_driven=8000.0, owner='Third Owner', age=6.0, power=390.0, brand='KTM'),
#   Row(bike_name='Yamaha YZF-R15 150cc', price=39000.0, city='Bangalore', kms_driven=29570.0, owner='Third Owner', age=12.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Kawasaki Z800', price=615000.0, city='Hyderabad', kms_driven=17500.0, owner='Third Owner', age=6.0, power=800.0, brand='Kawasaki'),
#   Row(bike_name='Kawasaki Z800', price=550000.0, city='Delhi', kms_driven=18500.0, owner='Third Owner', age=8.0, power=800.0, brand='Kawasaki'),
#   Row(bike_name='Yezdi Classic 250cc', price=68000.0, city='Ahmedabad', kms_driven=23.0, owner='Third Owner', age=39.0, power=250.0, brand='Yezdi'),
#   Row(bike_name='Hero Karizma ZMR 223cc', price=70000.0, city='Delhi', kms_driven=10000.0, owner='Third Owner', age=4.0, power=223.0, brand='Hero'),
#   Row(bike_name='Yamaha YZF-R15 150cc', price=34000.0, city='Narnaul', kms_driven=50000.0, owner='Third Owner', age=10.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Avenger 200cc', price=33000.0, city='Bangalore', kms_driven=31500.0, owner='Third Owner', age=14.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar RS200 ABS', price=85000.0, city='Anand', kms_driven=15200.0, owner='Third Owner', age=5.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Yamaha YZF-R15 150cc', price=34000.0, city='Narnaul', kms_driven=50000.0, owner='Third Owner', age=10.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='TVS Apache RTR 160cc', price=16000.0, city='Dehradun', kms_driven=75000.0, owner='Third Owner', age=14.0, power=160.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=55000.0, city='Delhi', kms_driven=4572.0, owner='Third Owner', age=17.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZs 150cc', price=18000.0, city='Delhi', kms_driven=64901.0, owner='Third Owner', age=11.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Avenger 220cc', price=32000.0, city='Ahmedabad', kms_driven=24530.0, owner='Third Owner', age=9.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=45000.0, city='Bangalore', kms_driven=93108.0, owner='Third Owner', age=18.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=28000.0, city='Lucknow', kms_driven=17250.0, owner='Third Owner', age=8.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Kawasaki Ninja 250cc', price=110000.0, city='Mumbai', kms_driven=24000.0, owner='Third Owner', age=9.0, power=250.0, brand='Kawasaki'),
#   Row(bike_name='KTM RC 200cc', price=84400.0, city='Mumbai', kms_driven=25000.0, owner='Third Owner', age=6.0, power=200.0, brand='KTM'),
#   Row(bike_name='Hero Splendor Pro 100cc', price=22500.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=8.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Avenger 220cc', price=32000.0, city='Gurgaon', kms_driven=25751.0, owner='Third Owner', age=8.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero CBZ Xtreme 150cc', price=25000.0, city='Ghaziabad', kms_driven=35244.0, owner='Third Owner', age=9.0, power=150.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=60000.0, city='Delhi', kms_driven=36000.0, owner='Third Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=120000.0, city='Bangalore', kms_driven=8000.0, owner='Third Owner', age=38.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='KTM RC 200cc', price=84400.0, city='Mumbai', kms_driven=25000.0, owner='Third Owner', age=6.0, power=200.0, brand='KTM'),
#   Row(bike_name='Hero Splendor Pro 100cc', price=22500.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=8.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Avenger 220cc', price=32000.0, city='Ahmedabad', kms_driven=24530.0, owner='Third Owner', age=9.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=45000.0, city='Bangalore', kms_driven=93108.0, owner='Third Owner', age=18.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=120000.0, city='Bangalore', kms_driven=8000.0, owner='Third Owner', age=38.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero CBZ Xtreme 150cc', price=25000.0, city='Ghaziabad', kms_driven=35244.0, owner='Third Owner', age=9.0, power=150.0, brand='Hero'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=28000.0, city='Lucknow', kms_driven=17250.0, owner='Third Owner', age=8.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Honda CB Twister 110cc', price=27000.0, city='Lucknow', kms_driven=36000.0, owner='Third Owner', age=11.0, power=110.0, brand='Honda'),
#   Row(bike_name='TVS Apache RTR 160cc', price=16000.0, city='Dehradun', kms_driven=75000.0, owner='Third Owner', age=14.0, power=160.0, brand='TVS'),
#   Row(bike_name='TVS Apache RTR 200 4V FI', price=65000.0, city='Sonepat', kms_driven=8800.0, owner='Third Owner', age=4.0, power=200.0, brand='TVS'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=55000.0, city='Faridabad', kms_driven=28864.0, owner='Third Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Honda CB Unicorn 150cc', price=25000.0, city='Mumbai', kms_driven=67503.0, owner='Third Owner', age=15.0, power=150.0, brand='Honda'),
#   Row(bike_name='TVS Apache RTR 160cc', price=41000.0, city='Delhi', kms_driven=26528.0, owner='Third Owner', age=5.0, power=160.0, brand='TVS'),
#   Row(bike_name='TVS Apache RTR 160cc', price=41000.0, city='Delhi', kms_driven=15880.0, owner='Third Owner', age=5.0, power=160.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=60000.0, city='Delhi', kms_driven=36000.0, owner='Third Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Kawasaki Ninja 250cc', price=110000.0, city='Mumbai', kms_driven=24000.0, owner='Third Owner', age=9.0, power=250.0, brand='Kawasaki'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=7000.0, city='Ahmedabad', kms_driven=80000.0, owner='Third Owner', age=15.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Harley-Davidson Street 750', price=250000.0, city='Ahmedabad', kms_driven=7600.0, owner='Third Owner', age=5.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Triumph Daytona 675 ABS', price=699000.0, city='Delhi', kms_driven=9000.0, owner='Third Owner', age=5.0, power=675.0, brand='Triumph'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=15344.0, city='Jamnagar', kms_driven=71943.0, owner='Third Owner', age=12.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='KTM Duke 200cc', price=55000.0, city='Mumbai', kms_driven=32000.0, owner='Third Owner', age=9.0, power=200.0, brand='KTM'),
#   Row(bike_name='Harley-Davidson Street 750', price=250000.0, city='Ahmedabad', kms_driven=7600.0, owner='Third Owner', age=5.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Hero Passion Plus 100cc', price=14500.0, city='Delhi', kms_driven=17999.0, owner='Third Owner', age=15.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=65000.0, city='Gurgaon', kms_driven=14101.0, owner='Third Owner', age=34.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Passion Plus 100cc', price=23000.0, city='Pune', kms_driven=40000.0, owner='Third Owner', age=16.0, power=100.0, brand='Hero'),
#   Row(bike_name='Hero CD Deluxe 100cc', price=17000.0, city='Jhansi', kms_driven=35000.0, owner='Third Owner', age=11.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Discover 135cc', price=20000.0, city='Swaimadhopur', kms_driven=35000.0, owner='Third Owner', age=12.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=85000.0, city='Bundi', kms_driven=15000.0, owner='Third Owner', age=7.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Karizma R 223cc', price=28000.0, city='Ghaziabad', kms_driven=27893.0, owner='Third Owner', age=8.0, power=223.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Classic 500cc', price=150000.0, city='Mathura', kms_driven=17000.0, owner='Third Owner', age=4.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Passion 100cc', price=12500.0, city='Ahmedabad', kms_driven=70403.0, owner='Third Owner', age=15.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Discover 135cc', price=20500.0, city='Mumbai', kms_driven=51630.0, owner='Third Owner', age=11.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion Pro 100cc', price=32000.0, city='Mumbai', kms_driven=68543.0, owner='Third Owner', age=15.0, power=100.0, brand='Hero'),
#   Row(bike_name='Honda CB Shine 125cc', price=27000.0, city='Mumbai', kms_driven=89454.0, owner='Third Owner', age=17.0, power=125.0, brand='Honda'),
#   Row(bike_name='Bajaj Avenger 220cc', price=34500.0, city='Bareilly', kms_driven=22000.0, owner='Third Owner', age=7.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='KTM RC 390cc', price=125000.0, city='Pune', kms_driven=18580.0, owner='Third Owner', age=6.0, power=390.0, brand='KTM'),
#   Row(bike_name='Royal Enfield Classic Desert Storm 500cc', price=92000.0, city='Ludhiana', kms_driven=23569.0, owner='Third Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Classic Desert Storm 500cc', price=92000.0, city='Ludhiana', kms_driven=23569.0, owner='Third Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 220F', price=21305.0, city='Ahmedabad', kms_driven=60000.0, owner='Third Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Yamaha FZ16 150cc', price=65000.0, city='Rajkot', kms_driven=18000.0, owner='Third Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=35800.0, city='Bangalore', kms_driven=90408.0, owner='Third Owner', age=18.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=35800.0, city='Bangalore', kms_driven=90408.0, owner='Third Owner', age=18.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar NS200', price=46000.0, city='Bangalore', kms_driven=27687.0, owner='Third Owner', age=9.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic Desert Storm 500cc', price=88000.0, city='Delhi', kms_driven=19000.0, owner='Second Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Benelli 302R 300CC', price=240000.0, city='Mumbai', kms_driven=15025.0, owner='Second Owner', age=3.0, power=302.0, brand='Benelli'),
#   Row(bike_name='Honda CBF Stunner 125cc', price=20800.0, city='Faridabad', kms_driven=30500.0, owner='Second Owner', age=7.0, power=125.0, brand='Honda'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=80000.0, city='Kaithal', kms_driven=20000.0, owner='Second Owner', age=4.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='KTM Duke 200cc', price=70000.0, city='Nashik', kms_driven=100000.0, owner='Second Owner', age=8.0, power=200.0, brand='KTM'),
#   Row(bike_name='Honda CB Shine 125cc', price=21900.0, city='Gorakhpur', kms_driven=30000.0, owner='Second Owner', age=7.0, power=125.0, brand='Honda'),
#   Row(bike_name='Benelli TNT 600i ABS', price=475000.0, city='Mumbai', kms_driven=11500.0, owner='Second Owner', age=3.0, power=600.0, brand='Benelli'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=107100.0, city='Delhi', kms_driven=15438.0, owner='Second Owner', age=3.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Karizma ZMR 223cc', price=55786.0, city='Surat', kms_driven=68000.0, owner='Second Owner', age=7.0, power=223.0, brand='Hero'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=82000.0, city='Mumbai', kms_driven=4300.0, owner='Second Owner', age=3.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='KTM Duke 250cc', price=130000.0, city='Gandhidham', kms_driven=17500.0, owner='Second Owner', age=4.0, power=250.0, brand='KTM'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=68500.0, city='Delhi', kms_driven=68500.0, owner='Second Owner', age=7.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='KTM RC 200cc', price=118000.0, city='Delhi', kms_driven=11200.0, owner='Second Owner', age=5.0, power=200.0, brand='KTM'),
#   Row(bike_name='Harley-Davidson Iron 883', price=435000.0, city='Jaipur', kms_driven=5550.0, owner='Second Owner', age=7.0, power=883.0, brand='Harley-Davidson'),
#   Row(bike_name='Bajaj Avenger Street 220', price=45400.0, city='Delhi', kms_driven=23000.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger 220cc', price=45600.0, city='Rewari', kms_driven=18000.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Yamaha SZ-RR 150cc', price=23600.0, city='Delhi', kms_driven=22672.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Hyosung Aquila GV250', price=150000.0, city='Ahmednagar', kms_driven=8000.0, owner='Second Owner', age=6.0, power=250.0, brand='Hyosung'),
#   Row(bike_name='Yamaha Fazer 25 250cc', price=80400.0, city='24 Pargana', kms_driven=5100.0, owner='Second Owner', age=4.0, power=250.0, brand='Yamaha'),
#   Row(bike_name='Honda CB Hornet 160R CBS', price=61200.0, city='Banka', kms_driven=29000.0, owner='Second Owner', age=3.0, power=160.0, brand='Honda'),
#   Row(bike_name='Bajaj Avenger Cruise 220', price=55250.0, city='Pune', kms_driven=7781.0, owner='Second Owner', age=3.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Harley-Davidson Street 750', price=417000.0, city='Delhi', kms_driven=13000.0, owner='Second Owner', age=5.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=15000.0, city='Mumbai', kms_driven=55000.0, owner='Second Owner', age=13.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Honda CBR 250R', price=62800.0, city='Mumbai', kms_driven=38400.0, owner='Second Owner', age=7.0, power=250.0, brand='Honda'),
#   Row(bike_name='TVS Apache 150cc', price=9350.0, city='Bangalore', kms_driven=39822.0, owner='Second Owner', age=13.0, power=150.0, brand='TVS'),
#   Row(bike_name='Hero Splendor Plus 100cc', price=38000.0, city='Pune', kms_driven=17376.0, owner='Second Owner', age=5.0, power=100.0, brand='Hero'),
#   Row(bike_name='Honda CBR 250R', price=62800.0, city='Mumbai', kms_driven=38400.0, owner='Second Owner', age=7.0, power=250.0, brand='Honda'),
#   Row(bike_name='TVS Apache 150cc', price=9350.0, city='Bangalore', kms_driven=39822.0, owner='Second Owner', age=13.0, power=150.0, brand='TVS'),
#   Row(bike_name='Honda CB Shine 125cc', price=33500.0, city='Pune', kms_driven=26000.0, owner='Second Owner', age=12.0, power=125.0, brand='Honda'),
#   Row(bike_name='Bajaj Pulsar 135LS', price=31000.0, city='Bangalore', kms_driven=31464.0, owner='Second Owner', age=9.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=115000.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CB Shine 125cc', price=33500.0, city='Pune', kms_driven=26000.0, owner='Second Owner', age=12.0, power=125.0, brand='Honda'),
#   Row(bike_name='Bajaj Pulsar 135LS', price=31000.0, city='Bangalore', kms_driven=31464.0, owner='Second Owner', age=9.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=115000.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='TVS Apache RTR 180cc', price=40000.0, city='Delhi', kms_driven=16688.0, owner='Second Owner', age=6.0, power=180.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=74500.0, city='Delhi', kms_driven=5432.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CBR 250R ABS', price=130000.0, city='Delhi', kms_driven=14500.0, owner='Second Owner', age=8.0, power=250.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Classic Chrome 500cc', price=128700.0, city='Bangalore', kms_driven=15900.0, owner='Second Owner', age=5.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Discover 125cc', price=17000.0, city='Bangalore', kms_driven=28130.0, owner='Second Owner', age=8.0, power=125.0, brand='Bajaj'),
#   Row(bike_name='Harley-Davidson Street 750', price=371100.0, city='Pune', kms_driven=6300.0, owner='Second Owner', age=5.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Royal Enfield Classic 500cc', price=93500.0, city='Gurgaon', kms_driven=10100.0, owner='Second Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CBR 250R ABS', price=130000.0, city='Delhi', kms_driven=14500.0, owner='Second Owner', age=8.0, power=250.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Classic 500cc', price=93500.0, city='Gurgaon', kms_driven=10100.0, owner='Second Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CBR 150R 150cc', price=60000.0, city='Mumbai', kms_driven=21000.0, owner='Second Owner', age=6.0, power=150.0, brand='Honda'),
#   Row(bike_name='Hero Splendor Plus 100cc', price=32000.0, city='Pune', kms_driven=21884.0, owner='Second Owner', age=8.0, power=100.0, brand='Hero'),
#   Row(bike_name='Hyosung GT650R', price=230000.0, city='Dadra & Nagar Haveli', kms_driven=16150.0, owner='Second Owner', age=8.0, power=650.0, brand='Hyosung'),
#   Row(bike_name='Ducati Diavel 1200cc', price=1000000.0, city='Coimbatore', kms_driven=4400.0, owner='Second Owner', age=5.0, power=1200.0, brand='Ducati'),
#   Row(bike_name='Bajaj Pulsar 220F', price=58500.0, city='Delhi', kms_driven=11500.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='TVS Apache RTR 200 4V Fi', price=70000.0, city='Delhi', kms_driven=9761.0, owner='Second Owner', age=5.0, power=200.0, brand='TVS'),
#   Row(bike_name='Bajaj Pulsar RS200', price=89100.0, city='Ujjain', kms_driven=13800.0, owner='Second Owner', age=4.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=58000.0, city='Delhi', kms_driven=35000.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha YZF-R15 2.0 150cc', price=58000.0, city='Delhi', kms_driven=35000.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha FZ S V 2.0 150cc-Ltd. Edition', price=68900.0, city='Faridabad', kms_driven=16980.0, owner='Second Owner', age=4.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Hero Ignitor 125cc', price=23000.0, city='Jhansi', kms_driven=25000.0, owner='Second Owner', age=6.0, power=125.0, brand='Hero'),
#   Row(bike_name='Yamaha SZ-RR 150cc', price=35000.0, city='Faridabad', kms_driven=30000.0, owner='Second Owner', age=5.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Classic 500cc', price=82000.0, city='Gurgaon', kms_driven=37654.0, owner='Second Owner', age=9.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='TVS Apache RTR 200 4V Fi', price=70000.0, city='Delhi', kms_driven=9761.0, owner='Second Owner', age=5.0, power=200.0, brand='TVS'),
#   Row(bike_name='Bajaj Pulsar RS200', price=89100.0, city='Ujjain', kms_driven=13800.0, owner='Second Owner', age=4.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=115700.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=4.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj V15 150cc', price=41000.0, city='Kolkata', kms_driven=19500.0, owner='Second Owner', age=4.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar NS 200', price=41300.0, city='Basti', kms_driven=49000.0, owner='Second Owner', age=7.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='TVS Apache RTR 160cc', price=43000.0, city='Delhi', kms_driven=28454.0, owner='Second Owner', age=4.0, power=160.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Bullet 350cc', price=99999.0, city='Balrampur', kms_driven=55.0, owner='Second Owner', age=15.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Thunderbird 500cc', price=87550.0, city='Noida', kms_driven=15000.0, owner='Second Owner', age=5.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Dominar 400', price=110000.0, city='Delhi', kms_driven=14000.0, owner='Second Owner', age=4.0, power=400.0, brand='Bajaj'),
#   Row(bike_name='Hero Splendor Pro 100cc', price=22100.0, city='Jhansi', kms_driven=24000.0, owner='Second Owner', age=7.0, power=100.0, brand='Hero'),
#   Row(bike_name='Hero CBZ Xtreme 150cc', price=34500.0, city='Pune', kms_driven=80000.0, owner='Second Owner', age=10.0, power=150.0, brand='Hero'),
#   Row(bike_name='Bajaj V15 150cc', price=35500.0, city='Delhi', kms_driven=17500.0, owner='Second Owner', age=5.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger 220cc', price=35000.0, city='Delhi', kms_driven=22000.0, owner='Second Owner', age=8.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Yamaha FZ V 2.0 150cc', price=35000.0, city='Delhi', kms_driven=19000.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Discover 100cc', price=24999.0, city='Bhopal', kms_driven=29500.0, owner='Second Owner', age=9.0, power=100.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar RS200', price=75000.0, city='Hyderabad', kms_driven=40000.0, owner='Second Owner', age=6.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Hero CD Deluxe 100cc', price=15200.0, city='Jhansi', kms_driven=36000.0, owner='Second Owner', age=12.0, power=100.0, brand='Hero'),
#   Row(bike_name='Yamaha FZ V 2.0 150cc', price=35000.0, city='Delhi', kms_driven=19000.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha Fazer 25 250cc', price=85000.0, city='Hyderabad', kms_driven=15000.0, owner='Second Owner', age=4.0, power=250.0, brand='Yamaha'),
#   Row(bike_name='Honda CB Shine 125cc', price=25000.0, city='Delhi', kms_driven=15500.0, owner='Second Owner', age=7.0, power=125.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=62000.0, city='Delhi', kms_driven=11000.0, owner='Second Owner', age=17.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Benelli TNT 300', price=200000.0, city='Pune', kms_driven=6400.0, owner='Second Owner', age=5.0, power=300.0, brand='Benelli'),
#   Row(bike_name='Bajaj Pulsar AS150', price=35000.0, city='Patna', kms_driven=35000.0, owner='Second Owner', age=5.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Hero Splendor 100cc', price=21000.0, city='Pune', kms_driven=24000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Honda CB Shine 125cc', price=25000.0, city='Delhi', kms_driven=15500.0, owner='Second Owner', age=7.0, power=125.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=62000.0, city='Delhi', kms_driven=11000.0, owner='Second Owner', age=17.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZs 150cc', price=23000.0, city='Gurgaon', kms_driven=31085.0, owner='Second Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Honda Dream Neo 110cc', price=23500.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=6.0, power=110.0, brand='Honda'),
#   Row(bike_name='TVS Flame 125cc', price=25000.0, city='Jammu', kms_driven=35000.0, owner='Second Owner', age=12.0, power=125.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Machismo 350cc', price=75000.0, city='Mumbai', kms_driven=17000.0, owner='Second Owner', age=13.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha YZF-R15 V3 150cc', price=130000.0, city='Jhansi', kms_driven=3300.0, owner='Second Owner', age=3.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Pulsar NS200', price=52000.0, city='Mumbai', kms_driven=26000.0, owner='Second Owner', age=6.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='TVS Flame 125cc', price=25000.0, city='Jammu', kms_driven=35000.0, owner='Second Owner', age=12.0, power=125.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=105000.0, city='Delhi', kms_driven=14000.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=58000.0, city='Hyderabad', kms_driven=42000.0, owner='Second Owner', age=4.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='TVS Apache RTR 160cc', price=18000.0, city='Mumbai', kms_driven=35408.0, owner='Second Owner', age=14.0, power=160.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Machismo 350cc', price=75000.0, city='Mumbai', kms_driven=17000.0, owner='Second Owner', age=13.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Karizma ZMR 223cc', price=45000.0, city='Bangalore', kms_driven=34000.0, owner='Second Owner', age=7.0, power=223.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=92000.0, city='Delhi', kms_driven=21000.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=105000.0, city='Delhi', kms_driven=14000.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Continental GT 535cc', price=130000.0, city='Hyderabad', kms_driven=15000.0, owner='Second Owner', age=6.0, power=535.0, brand='Royal Enfield'),
#   Row(bike_name='KTM Duke 200cc', price=68000.0, city='Mumbai', kms_driven=20000.0, owner='Second Owner', age=9.0, power=200.0, brand='KTM'),
#   Row(bike_name='Rajdoot GTX 175cc', price=75000.0, city='Delhi', kms_driven=500.0, owner='Second Owner', age=41.0, power=175.0, brand='Rajdoot'),
#   Row(bike_name='KTM Duke 200cc', price=68000.0, city='Mumbai', kms_driven=20000.0, owner='Second Owner', age=9.0, power=200.0, brand='KTM'),
#   Row(bike_name='Kawasaki Ninja 650cc', price=320000.0, city='Bangalore', kms_driven=12000.0, owner='Second Owner', age=7.0, power=650.0, brand='Kawasaki'),
#   Row(bike_name='Yamaha FZs 150cc', price=30500.0, city='Faridabad', kms_driven=22500.0, owner='Second Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Standard 350cc', price=90000.0, city='Delhi', kms_driven=14000.0, owner='Second Owner', age=7.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Passion Pro 100cc', price=23000.0, city='Jaisalmer', kms_driven=30000.0, owner='Second Owner', age=10.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 500cc', price=135000.0, city='Pune', kms_driven=9800.0, owner='Second Owner', age=6.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Mahindra Centuro 110cc', price=20000.0, city='Delhi', kms_driven=20000.0, owner='Second Owner', age=8.0, power=110.0, brand='Mahindra'),
#   Row(bike_name='Royal Enfield Standard 350cc', price=90000.0, city='Delhi', kms_driven=14000.0, owner='Second Owner', age=7.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='KTM Duke 200cc', price=127000.0, city='Noida', kms_driven=6700.0, owner='Second Owner', age=3.0, power=200.0, brand='KTM'),
#   Row(bike_name='KTM RC 390cc', price=150000.0, city='Jalandhar', kms_driven=9000.0, owner='Second Owner', age=4.0, power=390.0, brand='KTM'),
#   Row(bike_name='TVS Apache RTR 180cc ABS', price=48000.0, city='Delhi', kms_driven=20000.0, owner='Second Owner', age=5.0, power=180.0, brand='TVS'),
#   Row(bike_name='Yamaha FZ25 ABS 250cc', price=130000.0, city='Mumbai', kms_driven=1143.0, owner='Second Owner', age=2.0, power=250.0, brand='Yamaha'),
#   Row(bike_name='Suzuki Gixxer 150cc', price=55000.0, city='Coimbatore', kms_driven=18500.0, owner='Second Owner', age=5.0, power=150.0, brand='Suzuki'),
#   Row(bike_name='Royal Enfield Standard 350cc', price=88000.0, city='Ambala', kms_driven=18000.0, owner='Second Owner', age=9.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CBR 250R', price=57000.0, city='Delhi', kms_driven=32802.0, owner='Second Owner', age=10.0, power=250.0, brand='Honda'),
#   Row(bike_name='Bajaj Pulsar NS200', price=42000.0, city='Mumbai', kms_driven=40000.0, owner='Second Owner', age=6.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Continental GT 535cc', price=133100.0, city='Gorakhpur', kms_driven=2954.0, owner='Second Owner', age=4.0, power=535.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZ S V 2.0 150cc', price=60000.0, city='Mumbai', kms_driven=12332.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Hero Passion Pro 100cc', price=18000.0, city='Gurgaon', kms_driven=69758.0, owner='Second Owner', age=11.0, power=100.0, brand='Hero'),
#   Row(bike_name='Hero Karizma ZMR 223cc', price=29500.0, city='Pune', kms_driven=45000.0, owner='Second Owner', age=10.0, power=223.0, brand='Hero'),
#   Row(bike_name='TVS Apache RTR 180cc ABS', price=48000.0, city='Delhi', kms_driven=20000.0, owner='Second Owner', age=5.0, power=180.0, brand='TVS'),
#   Row(bike_name='Yamaha FZ25 ABS 250cc', price=130000.0, city='Mumbai', kms_driven=1143.0, owner='Second Owner', age=2.0, power=250.0, brand='Yamaha'),
#   Row(bike_name='Suzuki Gixxer 150cc', price=55000.0, city='Coimbatore', kms_driven=18500.0, owner='Second Owner', age=5.0, power=150.0, brand='Suzuki'),
#   Row(bike_name='Hero Splendor Plus 100cc', price=13700.0, city='Jhansi', kms_driven=26000.0, owner='Second Owner', age=13.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Avenger Street 220', price=59999.0, city='Delhi', kms_driven=27000.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='TVS Apache RTR 160 4V Disc', price=65000.0, city='Delhi', kms_driven=10000.0, owner='Second Owner', age=3.0, power=160.0, brand='TVS'),
#   Row(bike_name='Bajaj Avenger 220cc', price=47000.0, city='Pune', kms_driven=42000.0, owner='Second Owner', age=7.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Yamaha FZs 150cc', price=22000.0, city='Delhi', kms_driven=33000.0, owner='Second Owner', age=10.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Mahindra Centuro 110cc', price=35000.0, city='Delhi', kms_driven=29451.0, owner='Second Owner', age=6.0, power=110.0, brand='Mahindra'),
#   Row(bike_name='Honda CB Trigger 150cc', price=30000.0, city='Noida', kms_driven=17300.0, owner='Second Owner', age=8.0, power=150.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=128000.0, city='Coimbatore', kms_driven=40000.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZs 150cc', price=28300.0, city='Delhi', kms_driven=35000.0, owner='Second Owner', age=7.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha Fazer 150cc', price=30000.0, city='Delhi', kms_driven=13250.0, owner='Second Owner', age=8.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha FZs 150cc', price=23300.0, city='Delhi', kms_driven=12580.0, owner='Second Owner', age=11.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Honda CBR 250R', price=57000.0, city='Delhi', kms_driven=32802.0, owner='Second Owner', age=10.0, power=250.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Standard 350cc', price=250000.0, city='Chennai', kms_driven=1400.0, owner='Second Owner', age=27.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Honda CB Trigger 150cc', price=30000.0, city='Noida', kms_driven=17300.0, owner='Second Owner', age=8.0, power=150.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Continental GT 535cc', price=133100.0, city='Gorakhpur', kms_driven=2954.0, owner='Second Owner', age=4.0, power=535.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZ S V 2.0 150cc', price=60000.0, city='Mumbai', kms_driven=12332.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Hero Passion Pro 100cc', price=18000.0, city='Gurgaon', kms_driven=69758.0, owner='Second Owner', age=11.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=63618.0, city='Ghaziabad', kms_driven=16000.0, owner='Second Owner', age=7.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='KTM RC 390cc', price=150000.0, city='Jalandhar', kms_driven=9000.0, owner='Second Owner', age=4.0, power=390.0, brand='KTM'),
#   Row(bike_name='TVS Apache RTR 160 4V Disc', price=65000.0, city='Delhi', kms_driven=10000.0, owner='Second Owner', age=3.0, power=160.0, brand='TVS'),
#   Row(bike_name='Bajaj Avenger 220cc', price=47000.0, city='Pune', kms_driven=42000.0, owner='Second Owner', age=7.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Yamaha FZs 150cc', price=22000.0, city='Delhi', kms_driven=33000.0, owner='Second Owner', age=10.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Bajaj Pulsar 220cc', price=49500.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield\u200e Bullet 350cc', price=95000.0, city='Delhi', kms_driven=26000.0, owner='Second Owner', age=9.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha FZ S V 2.0 150cc', price=46000.0, city='Noida', kms_driven=28700.0, owner='Second Owner', age=6.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha FZ 150cc', price=25000.0, city='Navi Mumbai', kms_driven=26000.0, owner='Second Owner', age=12.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=71000.0, city='Delhi', kms_driven=11000.0, owner='Second Owner', age=10.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='TVS Apache RTR 180cc', price=70000.0, city='Delhi', kms_driven=7000.0, owner='Second Owner', age=3.0, power=180.0, brand='TVS'),
#   Row(bike_name='Hero CBZ Xtreme 150cc', price=46000.0, city='Pune', kms_driven=39000.0, owner='Second Owner', age=10.0, power=150.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Classic Desert Storm 500cc', price=135000.0, city='Gurgaon', kms_driven=19926.0, owner='Second Owner', age=7.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 220cc', price=49500.0, city='Delhi', kms_driven=15000.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=63618.0, city='Ghaziabad', kms_driven=16000.0, owner='Second Owner', age=7.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar AS200', price=46300.0, city='Ramanagar', kms_driven=32000.0, owner='Second Owner', age=6.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='Yamaha YZF-R15 150cc', price=46500.0, city='Ahmedabad', kms_driven=30600.0, owner='Second Owner', age=9.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Himalayan 410cc', price=92500.0, city='Mumbai', kms_driven=21407.0, owner='Second Owner', age=5.0, power=410.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Honda Splendor 100cc', price=10000.0, city='Ghaziabad', kms_driven=61145.0, owner='Second Owner', age=10.0, power=100.0, brand='Hero'),
#   Row(bike_name='KTM Duke 200cc', price=95000.0, city='Delhi', kms_driven=8200.0, owner='Second Owner', age=6.0, power=200.0, brand='KTM'),
#   Row(bike_name='KTM Duke 200cc', price=95000.0, city='Delhi', kms_driven=8200.0, owner='Second Owner', age=6.0, power=200.0, brand='KTM'),
#   Row(bike_name='Harley-Davidson Street 750', price=395000.0, city='Mumbai', kms_driven=2500.0, owner='Second Owner', age=4.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Bajaj Discover 125cc', price=20300.0, city='Jhansi', kms_driven=28000.0, owner='Second Owner', age=6.0, power=125.0, brand='Bajaj'),
#   Row(bike_name='Hero CBZ 150cc', price=28000.0, city='Patna', kms_driven=61000.0, owner='Second Owner', age=13.0, power=150.0, brand='Hero'),
#   Row(bike_name='Honda CBR 600RR', price=500000.0, city='Solapur', kms_driven=8000.0, owner='Second Owner', age=14.0, power=600.0, brand='Honda'),
#   Row(bike_name='Ducati Panigale 959', price=1220000.0, city='Pune', kms_driven=4400.0, owner='Second Owner', age=5.0, power=959.0, brand='Ducati'),
#   Row(bike_name='Honda CB Unicorn 160 STD', price=35000.0, city='Mumbai', kms_driven=9000.0, owner='Second Owner', age=6.0, power=160.0, brand='Honda'),
#   Row(bike_name='Royal Enfield Himalayan 410cc', price=92500.0, city='Mumbai', kms_driven=21407.0, owner='Second Owner', age=5.0, power=410.0, brand='Royal Enfield'),
#   Row(bike_name='Hero Honda Splendor 100cc', price=10000.0, city='Ghaziabad', kms_driven=61145.0, owner='Second Owner', age=10.0, power=100.0, brand='Hero'),
#   Row(bike_name='TVS Apache RTR 180cc ABS', price=47500.0, city='Mumbai', kms_driven=38311.0, owner='Second Owner', age=4.0, power=180.0, brand='TVS'),
#   Row(bike_name='Yamaha FZ 150cc', price=18000.0, city='Bangalore', kms_driven=28000.0, owner='Second Owner', age=12.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Yamaha FZ 150cc', price=18000.0, city='Bangalore', kms_driven=28000.0, owner='Second Owner', age=12.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='TVS Apache RTR 180cc ABS', price=47500.0, city='Mumbai', kms_driven=38311.0, owner='Second Owner', age=4.0, power=180.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Bullet 350 cc', price=45000.0, city='Gurgaon', kms_driven=40000.0, owner='Second Owner', age=20.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Bullet 350 cc', price=45000.0, city='Gurgaon', kms_driven=40000.0, owner='Second Owner', age=20.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='KTM Duke 250cc', price=120000.0, city='Chennai', kms_driven=10536.0, owner='Second Owner', age=4.0, power=250.0, brand='KTM'),
#   Row(bike_name='Kawasaki Z250', price=145000.0, city='Delhi', kms_driven=10800.0, owner='Second Owner', age=6.0, power=250.0, brand='Kawasaki'),
#   Row(bike_name='Hero Glamour 125cc', price=13000.0, city='Ahmedabad', kms_driven=45466.0, owner='Second Owner', age=14.0, power=125.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Bullet Electra 350cc', price=82000.0, city='Rohtak', kms_driven=30000.0, owner='Second Owner', age=12.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=31100.0, city='Kolhapur', kms_driven=11500.0, owner='Second Owner', age=9.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 500cc', price=125000.0, city='Gautam Buddha Nagar', kms_driven=21057.0, owner='Second Owner', age=5.0, power=500.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Continental GT 535cc', price=115000.0, city='Thane', kms_driven=7247.0, owner='Second Owner', age=6.0, power=535.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=60000.0, city='Delhi', kms_driven=30591.0, owner='Second Owner', age=8.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger Cruise 220', price=50000.0, city='Delhi', kms_driven=32276.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=100000.0, city='Bangalore', kms_driven=25555.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 220F', price=39000.0, city='Kanchipuram', kms_driven=25600.0, owner='Second Owner', age=7.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar RS200', price=110000.0, city='Pune', kms_driven=16000.0, owner='Second Owner', age=5.0, power=200.0, brand='Bajaj'),
#   Row(bike_name='TVS Apache RTR 180cc', price=49999.0, city='Delhi', kms_driven=20000.0, owner='Second Owner', age=6.0, power=180.0, brand='TVS'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=92000.0, city='Gandhinagar', kms_driven=25000.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Hero HF Deluxe Self 100cc', price=37300.0, city='Jhansi', kms_driven=13000.0, owner='Second Owner', age=4.0, power=100.0, brand='Hero'),
#   Row(bike_name='Bajaj Pulsar 135LS', price=16000.0, city='Gurgaon', kms_driven=42107.0, owner='Second Owner', age=10.0, power=135.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=98000.0, city='Delhi', kms_driven=9816.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Royal Enfield Bullet 350cc', price=95000.0, city='Chandigarh', kms_driven=20069.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Yamaha Fazer 150cc', price=17000.0, city='Noida', kms_driven=100000.0, owner='Second Owner', age=11.0, power=150.0, brand='Yamaha'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=80000.0, city='Ratnagiri', kms_driven=13260.0, owner='Second Owner', age=5.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=16400.0, city='Chennai', kms_driven=55000.0, owner='Second Owner', age=11.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=12000.0, city='Delhi', kms_driven=32148.0, owner='Second Owner', age=14.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger 220cc', price=45000.0, city='Jaipur', kms_driven=15091.0, owner='Second Owner', age=7.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger Street 220', price=60000.0, city='Noida', kms_driven=15097.0, owner='Second Owner', age=5.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Bajaj Avenger 220cc', price=40000.0, city='Bangalore', kms_driven=26070.0, owner='Second Owner', age=8.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Harley-Davidson Street 750', price=370000.0, city='Mumbai', kms_driven=4899.0, owner='Second Owner', age=5.0, power=750.0, brand='Harley-Davidson'),
#   Row(bike_name='Bajaj Pulsar 150cc', price=12000.0, city='Delhi', kms_driven=32148.0, owner='Second Owner', age=14.0, power=150.0, brand='Bajaj'),
#   Row(bike_name='Royal Enfield Classic 350cc', price=100000.0, city='Delhi', kms_driven=14576.0, owner='Second Owner', age=6.0, power=350.0, brand='Royal Enfield'),
# ...
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   Row(bike_name='Hero Passion 100cc', price=15000.0, city='Perumbavoor', kms_driven=35000.0, owner='Second Owner', age=19.0, power=100.0, brand='Hero'),
#   Row(bike_name='Royal Enfield Thunderbird 350cc', price=70000.0, city='Mumbai', kms_driven=13858.0, owner='Second Owner', age=11.0, power=350.0, brand='Royal Enfield'),
#   Row(bike_name='Bajaj Avenger 220cc', price=41000.0, city='Delhi', kms_driven=20245.0, owner='Second Owner', age=11.0, power=220.0, brand='Bajaj'),
#   ...]]

# %%
df_repartition.rdd.getNumPartitions()
# Out:
# 1

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# '200'

# %%
print (df_repartition.rdd.partitioner)
# Out:
# None

# %%
df = records.rdd.map(lambda el: (el['owner'], el)).partitionBy( 'owner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ck/pshs4v1n6nz0jfq8lmbn24zc0000gn/T/ipykernel_3627/2702987488.py in <module>
# ----> 1 df = records.rdd.map(lambda el: (el['owner'], el)).partitionBy( 'owner')
#
# NameError: name 'records' is not defined
